# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(5)
print(x)
# Out:
# [0 1 2 3 4]

# %%
y=[1,2,3,4,5]

# %%
plt.title("hi")
plt.plot(x,y,'+r--')
plt.show()
#rgb can be used
plt.title("hi")
# Out:
# Text(0.5, 1.0, 'hi')

# %%
k=int(np.linspace(0,10,10))
print(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-2de94715c54b> in <module>
# ----> 1 k=int(np.linspace(0,10,10))
#       2 print(k)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
k=(np.linspace(0,10,5))
print(k)
# Out:
# [ 0.   2.5  5.   7.5 10. ]

# %%
plt.axis("off")
plt.plot(x,y)

# %%
#similarly np.logspace

# %%
plt.title("hi")
plt.xlabel("yo")
plt.plot(x,y,'+r--')
plt.show()

# %%
#trying overlay plot

# %%
z=np.logspace(0.1,1,10)
d=np.logspace(1,0.1,10)
plt.plot(x,y,z,d)
plt.show()

# %%
y=np.geomspace(0,10,5)
print(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-698e91dfa32f> in <module>
# ----> 1 y=np.geomspace(0,10,5)
#       2 print(y)
#
# <__array_function__ internals> in geomspace(*args, **kwargs)
#
# c:\users\new\appdata\local\programs\python\python37\lib\site-packages\numpy\core\function_base.py in geomspace(start, stop, num, endpoint, dtype, axis)
#     385     stop = asanyarray(stop)
#     386     if _nx.any(start == 0) or _nx.any(stop == 0):
# --> 387         raise ValueError('Geometric sequence cannot include zero')
#     388
#     389     dt = result_type(start, stop, float(num), _nx.zeros((), dtype))
#
# ValueError: Geometric sequence cannot include zero

# %%
y=np.geomspace(0.1,10,5)
print(y)
# Out:
# [ 0.1         0.31622777  1.          3.16227766 10.        ]

# %%
#random sampling

# %%
print(np.random.randint(low=0,high=10,size=10))
# Out:
# [5 2 0 0 4 4 1 6 0 3]

# %%
#for random array

# %%
print(np.random.rand(4,4))
# Out:
# [[0.76082305 0.48148555 0.780766   0.03889071]
#  [0.5826903  0.82803252 0.52133958 0.79449147]
#  [0.04886399 0.05470755 0.69842383 0.92269173]
#  [0.50511558 0.81481833 0.64146663 0.74248466]]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-9f0394fcac7d> in <module>
# ----> 1 print(int(np.random.rand(4,4)))
#
# TypeError: only size-1 arrays can be converted to Python scalars
